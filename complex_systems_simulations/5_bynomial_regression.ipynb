# %%
import random
import matplotlib.pyplot as plt

# gerar número aleatório -> inventar f linear e gerar error (feito em distribuição normal)
N = 100
x_values, y_values = [], []

#print(random.uniform(0, 1))

def linear_func(x):
    return x - 20

def generate_error():
    random.uniform(0, 1)
    
for i in range(N):
    x_values.append(i)
    y_values.append(linear_func(i))
    
plt.plot(x_values, y_values)

# %%
# pegar dados binomial -> fazer regressão
plt.hist(x_values, density=True, bins=101)
plt.show()
