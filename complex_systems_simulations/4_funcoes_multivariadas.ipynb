# %% [markdown]
# <script type="text/x-mathjax-config">
#   MathJax.Hub.Config({tex2jax: {inlineMath: [['$','$'], ['\\(','\\)']]}});
# </script>
# <script type="text/javascript"
#   src="http://cdn.mathjax.org/mathjax/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML">
# </script>
#
# ## Funções multivariadas
#
# <body>
#
# É preciso descrever mais do que uma variável para determinados problemas, porque com apenas uma variável não é possível.
#
# Ex: Fração PPI (pretos, pardos, indígenas) é dependente da variável localidade.
#
# As funções multivariáveis são funções que recebem múltiplas variáveis como parâmetros:
#
# $\quad f(x, y) = x^2y $
#
# Se a saída de uma função for composta de múltiplos números, a função também pode ser chamada de multivariável, mas estas são mais comumente conhecidas como **funções vetoriais**
#
# $\quad f(x) = \biggl[ \begin{array}{ll} cos(x) \\ sen(x) \end{array} \biggl]$
#
# A visualização dessas funções normalmente é feira em um espaço com várias dimensões.
# </body>

# %% [markdown]
# Tabela:
#
# <table class="tg" style="width:100%">
#   <tr>
#     <th class="tg-0pky"></th>
#     <th class="tg-0pky">azul</th>
#     <th class="tg-0pky">branco</th>
#     <th class="tg-0pky">vermelho</th>
#   </tr>
#   <tr>
#     <td class="tg-0pky">1</td>
#     <td class="tg-0pky">1/6<br></td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">2</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">3</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">4</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">5</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#   </tr>
# </table>

# %% [markdown]
# Caso as variáveis sejam independentes, podemos fazer a distribuição de variável conjunta:
#
# <table class="tg" style="width:100%">
#   <tr>
#     <th class="tg-0pky"></th>
#     <th class="tg-0pky">azul</th>
#     <th class="tg-0pky">branco</th>
#     <th class="tg-0pky">vermelho</th>
#       <th class="tg-0pky">subtotal</th>
#   </tr>
#   <tr>
#     <td class="tg-0pky">1</td>
#     <td class="tg-0pky">1/6<br></td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#       <td class="tg-0pky">1/6</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">2</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#       <td class="tg-0pky">1/6</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">3</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#       <td class="tg-0pky">1/6</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">4</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#       <td class="tg-0pky">1/6</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">5</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#       <td class="tg-0pky">1/6</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky">6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#     <td class="tg-0pky">1/6</td>
#       <td class="tg-0pky">1/6</td>
#   </tr>
#     <tr>
#     <td class="tg-0pky">subtotal</td>
#     <td class="tg-0pky">1/3</td>
#     <td class="tg-0pky">1/3</td>
#     <td class="tg-0pky">1/3</td>
#       <td class="tg-0pky">1</td>
#   </tr>
# </table>

# %% [markdown]
# $X ~ U(0, 1)$
# $Y ~ U(0, 1)$
#
# Como monstar a função de distribuição de probabilidade?
#
# $ f(x, y) = fx(x) * f y|x (y|x) = $
#
# $ fy = \int_{- \infty}^{+ \infty} (fx,y)dx = $

# %%
import math, random
import numpy as np
import matplotlib.pyplot as plt
import time

xl, yl, N = np.array([]), np.array([]), 1000
    
def cov(x):
    return [[1, 0], [0, 1]]
    
def subM(x, u):
    return x

def f(x):
    n = 2
    E = cov(x)
    mSub = subM(x - u)
    return (1/math.sqrt((2 * math.pi) ** n) * E) * math.exp(-1/2 * mSub.transpose() * np.linalg.inv(E) * mSub)

def g(x):
    return f(0)

def step0():
    return random.uniform(-3, 3)

def step1(x0):
    A = (f(x0)/g(x0)) * (1 / math.sqrt(2 * math.pi))
    return A

def step2():
    y0 = random.uniform(0, 1)
    return y0

def step3(x0, y0, A):
    global xl, yl
    if y0 <= A:
        xl = np.append(xl, x0)
        yl = np.append(yl, y0)
        
def constGen():
    start = time.time()
    for i in range(N):
        x0 = step0()
        y0 = step0()
        A = step1(x0)
        y0 = step2()
        step3(x0, y0, A)
    end = time.time()
    print(f'Time spent = {end - start}')
    plt.plot(xl, yl, 'ro')
    plt.plot(xl, [1] * len(xl), 'b')
    plt.show()
    
constGen()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-68b9985c61dc> in <module>
#      50     plt.show()
#      51
# ---> 52 constGen()
#
# <ipython-input-8-68b9985c61dc> in constGen()
#      41         x0 = step0()
#      42         y0 = step0()
# ---> 43         A = step1(x0)
#      44         y0 = step2()
#      45         step3(x0, y0, A)
#
# <ipython-input-8-68b9985c61dc> in step1(x0)
#      23
#      24 def step1(x0):
# ---> 25     A = (f(x0)/g(x0)) * (1 / math.sqrt(2 * math.pi))
#      26     return A
#      27
#
# <ipython-input-8-68b9985c61dc> in f(x)
#      14     mSub = x #subM(x - u)
#      15     #return (1/math.sqrt((2 * math.pi) ** n) * E) * math.exp(-1/2 * mSub.transpose() * np.linalg.inv(E) * mSub)
# ---> 16     return math.exp(-1/2 * mSub.transpose() * np.linalg.inv(E) * mSub)
#      17
#      18 def g(x):
#
# ...
