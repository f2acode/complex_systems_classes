# %% [markdown]
# ## Classification of Depression on Social Media Using Text Mining

# %% [markdown]
# The aim of the project is to predict early signs of depression through **Social Media** text mining.
#
# ![img](https://camo.githubusercontent.com/97fa56b4cf5d83227f2f99eec853e56e0e9f87d1/68747470733a2f2f692e6962622e636f2f35764874746e532f62622e706e67)

# %% [markdown]
# ## Steps
#
# Here are the step-by-step used in this work

# %% [markdown]
# ### 0. Import packages and define helper functions

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler, Stream
import csv, json, string, re, time, itertools
from nltk.tokenize import word_tokenize
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import metrics
#from sklearn.metrics import roc_auc_score

def print_x(text):
    print(f'LOG => {text}\n')

# %% [markdown]
# ### 1. Create a twitter developer account
#
# After creating the developer account you can get the proper keys to be able to download the data.

# %%
consumer_key = 'EPINOmoZrP12DET2FJDIAj1pJ'
consumer_secret = '2Jr01uaTuKUVLqkk4NVIzT8D9P7EWo5DfVqejbgsUKZUYhbGlO'
access_token = '816743719143698433-pLpzyZCnbDphHHX6PrtQeMM5dQ0NyBl'
access_secret = 'g9qz34R2HMyc3KPz77tltNcqOUYcSI3TpHgV7brOfCDmf'

# %% [markdown]
# ### 2. Download data
#
# Use the credentials to download the current tweets using keywords such as depression, anxiety or sadness.
#
# Below you can see some of the tweets.

# %%
class StdOutListener(StreamListener):
    def __init__(self):
        super().__init__()
        self.tweet_count = 0
        self.tweets_limit = 10
        
    def on_data(self, data):
        with open('data/tweetdata.txt','a') as tf:
            tf.write(data)
        print_x(data)
        self.tweet_count += 1
        if self.tweet_count < self.tweets_limit:
            return True
        else:
            stream.disconnect()

    def on_error(self, status):
        print_x(status)

l = StdOutListener()
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
stream = Stream(auth, l)
stream.filter(track=['depression', 'anxiety', 'mental health', 'suicide', 'stress', 'sad'])
# Out:
# LOG => {"created_at":"Fri Jun 28 00:37:30 +0000 2019","id":1144404419146108928,"id_str":"1144404419146108928","text":"RT @Toooto_13: Alors la je suis subjugu\u00e9, le niveau est incroyable on a plus vu une telle performance depuis Zidane et le France-Br\u00e9sil de\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1680705768,"id_str":"1680705768","name":"La Capuche \u269c\ufe0f","screen_name":"Chxxx971","location":"Konoha","url":"https:\/\/www.instagram.com\/chris.971__\/","description":"Toujours croire en ses r\u00eaves et travailler dur pour y arriver.","translator_type":"none","protected":false,"verified":false,"followers_count":500,"friends_count":354,"listed_count":5,"favourites_count":6518,"statuses_count":21691,"created_at":"Sun Aug 18 13:32:32 +0000 2013","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"ABB8C2","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1143199224928059392\/lcReJh_y_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1143199224928059392\/lcReJh_y_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/1680705768\/1558290159","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Jun 27 16:21:10 +0000 2019","id":1144279512143863808,"id_str":"1144279512143863808","text":"Alors la je suis subjugu\u00e9, le niveau est incroyable on a plus vu une telle performance depuis Zidane et le France-B\u2026 https:\/\/t.co\/ISVaeSPiHe","display_text_range":[0,140],"source":"\u003ca href=\"https:\/\/mobile.twitter.com\" rel=\"nofollow\"\u003eTwitter Web App\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":365120312,"id_str":"365120312","name":"Toto Jr.","screen_name":"Toooto_13","location":"South Park, Colorado, USA","url":null,"description":"Si tu as de gros seins je follow-back. Olympique de Marseille \u2022 New York Knicks #1899Fans #NBA #2ndDegres","translator_type":"none","protected":false,"verified":false,"followers_count":31657,"friends_count":116,"listed_count":457,"favourites_count":294,"statuses_count":85819,"created_at":"Tue Aug 30 22:05:39 +0000 2011","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"DD2E44","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":true,"profile_link_color":"1B95E0","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\
835\udd59\ud835\udd5a\ud835\udd5f \ud835\udd59\ud835\udd56\ud835\udd63, \ud835\udd64\ud835\udd59\ud835\udd56 \ud835\udd68\ud835\udd5a\ud835\udd5d\ud835\udd5d \ud835\udd5f\ud835\udd60\ud835\udd65 \ud835\udd57\ud835\udd52\ud835\udd5a\ud835\udd5d\ud83d\udc95 \u2800 \u2800\u2800 \u2800","translator_type":"none","protected":false,"verified":false,"followers_count":2966,"friends_count":1370,"listed_count":4,"favourites_count":10597,"statuses_count":57840,"created_at":"Wed Jan 08 01:29:21 +0000 2014","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"FF6699","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":true,"profile_link_color":"DB2360","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_tex ...
# LOG => {"created_at":"Fri Jun 28 00:37:30 +0000 2019","id":1144404420807012359,"id_str":"1144404420807012359","text":"RT @ultchanyeolpark: This thread is just so sad. Look at how many times Chanyeol had to explain himself. \"I'm sorry I won't disappoint you\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":4742811105,"id_str":"4742811105","name":"poti. \u2661","screen_name":"CORIDELENT","location":"Prov. 31:25","url":"http:\/\/coridelentpr.tumblr.com","description":"no \u201cone of the most successful companies in south korea\u201d no opinion | creator & founder of @jjeos_official and @support_golden","translator_type":"none","protected":false,"verified":false,"followers_count":1446,"friends_count":173,"listed_count":43,"favourites_count":35053,"statuses_count":22973,"created_at":"Fri Jan 08 08:50:22 +0000 2016","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"9A7D0A","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1144134389577768960\/tlveNi9v_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1144134389577768960\/tlveNi9v_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/4742811105\/1560899910","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Jun 27 04:22:18 +0000 2019","id":1144098606355492865,"id_str":"1144098606355492865","text":"This thread is just so sad. Look at how many times Chanyeol had to explain himself. \"I'm sorry I won't disappoint y\u2026 https:\/\/t.co\/3DRTDijrd6","display_text_range":[0,140],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":54954866,"id_str":"54954866","name":"\u064b","screen_name":"ultchanyeolpark","location":"chanyeol stan","url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":32613,"friends_count":358,"listed_count":557,"favourites_count":22457,"statuses_count":75560,"created_at":"Wed Jul 08 16:58:26 +0000 2009","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme4\/bg.gif","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme4\/bg.gif","profile_background_tile":false,"profile_link_color":"E81C4F","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1139328633988898818\/3MA5AoXz_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1139328633988898818\/3MA5AoXz_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/54954866\/1561249642","default_profile":false,"default_profile_image":false,"following":null,"follo ...
#
#
#
# LOG => {"created_at":"Fri Jun 28 00:37:30 +0000 2019","id":1144404421155180547,"id_str":"1144404421155180547","text":"RT @DSPOmil: Registration is now open for the 2019 VA\/DOD Suicide Prevention Conference!  To register visit: https:\/\/t.co\/8KCfUkV6vX. See y\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1039971843225075712,"id_str":"1039971843225075712","name":"Melissa Brown","screen_name":"MMBrown14","location":"Atlanta, GA","url":null,"description":"Suicide researcher. Workaholic. Nearly a hermit and crazy cat lady. Handicapable handler of Puff the Magic Dragon service dog.","translator_type":"none","protected":false,"verified":false,"followers_count":253,"friends_count":193,"listed_count":6,"favourites_count":6026,"statuses_count":4684,"created_at":"Wed Sep 12 20:19:43 +0000 2018","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1039972526791831552\/GjKOKcND_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1039972526791831552\/GjKOKcND_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/1039971843225075712\/1536784378","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Jun 27 17:56:55 +0000 2019","id":1144303610269974529,"id_str":"1144303610269974529","text":"Registration is now open for the 2019 VA\/DOD Suicide Prevention Conference!  To register visit:\u2026 https:\/\/t.co\/AWMMP4Ng2R","display_text_range":[0,140],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":760504740262412288,"id_str":"760504740262412288","name":"DSPOmil","screen_name":"DSPOmil","location":null,"url":"http:\/\/www.DSPO.mil","description":"DSPO provides advocacy and policy oversight across the Armed Forces to reduce suicidal behaviors in Service members, their families and DoD civilians.","translator_type":"none","protected":false,"verified":false,"followers_count":606,"friends_count":351,"listed_count":24,"favourites_count":907,"statuses_count":1845,"created_at":"Tue Aug 02 15:57:14 +0000 2016","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/775371769595113472\/b-cXoJDx_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/775371769595113472\/b-cXoJDx_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/760504740262412288\/1538408727","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":nul ...
#
#
#
# LOG => {"created_at":"Fri Jun 28 00:37:30 +0000 2019","id":1144404421310328832,"id_str":"1144404421310328832","text":"@Beerzy66 @CharriseLane @Rambobiggs What\u2019s sad is there are people out there who would hurt her.","display_text_range":[36,96],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":1055571072882483200,"in_reply_to_status_id_str":"1055571072882483200","in_reply_to_user_id":38502632,"in_reply_to_user_id_str":"38502632","in_reply_to_screen_name":"Beerzy66","user":{"id":965958942869409792,"id_str":"965958942869409792","name":"Rebel Son","screen_name":"beatintheodds","location":"Down a dirt road in Georgia","url":null,"description":"Here for a few laughs, and to support my President, maybe make a friend. Blues and American roots music. Father of a US Marine. I shop at Walmart","translator_type":"none","protected":false,"verified":false,"followers_count":2184,"friends_count":2622,"listed_count":1,"favourites_count":8871,"statuses_count":5445,"created_at":"Tue Feb 20 14:38:53 +0000 2018","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1140354508511469570\/6tRimq3h_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1140354508511469570\/6tRimq3h_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/965958942869409792\/1560794068","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"quote_count":0,"reply_count":0,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"urls":[],"user_mentions":[{"screen_name":"Beerzy66","name":"Jenn V Beer","id":38502632,"id_str":"38502632","indices":[0,9]},{"screen_name":"CharriseLane","name":"\u274cCharrise Lane\u274c","id":1032464083268841473,"id_str":"1032464083268841473","indices":[10,23]},{"screen_name":"Rambobiggs","name":"Joe Biggs","id":70024758,"id_str":"70024758","indices":[24,35]}],"symbols":[]},"favorited":false,"retweeted":false,"filter_level":"low","lang":"en","timestamp_ms":"1561682250703"}
#
#
#
# LOG => {"created_at":"Fri Jun 28 00:37:30 +0000 2019","id":1144404421440262144,"id_str":"1144404421440262144","text":"RT @rjmxrell: so tired of being sad all the time","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":1120849950911262720,"id_str":"1120849950911262720","name":"Meng","screen_name":"luisasantuele07","location":"Taguig City, National Capital ","url":null,"description":"Nobleza","translator_type":"none","protected":false,"verified":false,"followers_count":43,"friends_count":345,"listed_count":0,"favourites_count":548,"statuses_count":479,"created_at":"Wed Apr 24 00:40:27 +0000 2019","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1143833029124612096\/xRx1xrGE_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1143833029124612096\/xRx1xrGE_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/1120849950911262720\/1558481272","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Jun 27 12:21:36 +0000 2019","id":1144219223310458880,"id_str":"1144219223310458880","text":"so tired of being sad all the time","source":"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2584598134,"id_str":"2584598134","name":"fuck feelings","screen_name":"rjmxrell","location":"Emilia Romagna, Italy","url":null,"description":"my twitter. my tweets. my life  ||  m x r e l l","translator_type":"none","protected":false,"verified":false,"followers_count":747181,"friends_count":0,"listed_count":1223,"favourites_count":49,"statuses_count":26168,"created_at":"Thu Jun 05 16:33:37 +0000 2014","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1067860547578851329\/VCU4EyiQ_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1067860547578851329\/VCU4EyiQ_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/2584598134\/1548105275","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"quote_count":84,"reply_count":6,"retweet_count":2806,"favorite_count":3990,"entities":{"hashtags":[],"urls":[],"user_mentions":[],"symbols":[]},"favorited":false,"retweeted":false,"filter_level":"low","lang":"en"},"is_quote_status":false,"quote_count":0,"reply_count":0,"retweet_count":0 ...
# LOG => {"created_at":"Fri Jun 28 00:37:31 +0000 2019","id":1144404424145756160,"id_str":"1144404424145756160","text":"@skinnydippng i am so Sad that it\u2019s on the opposite side of the country for me","display_text_range":[14,78],"source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":
+0000 2017","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1063828594768601088\/lhWTqQwF_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1063828594768601088\/lhWTqQwF_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/886563803730595842\/1558192070","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Thu Jun 27 20:48:19 +0000 2019","id":1144346746429923330,"id_str":"1144346746429923330","text":"So, @RTXEvent is upon us already? Still, I cannot attend, I even repost my old image from last year's RTX, sad life\u2026 https:\/\/t.co\/E6yrBfIs2C","display_text_range":[0,140],"source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":true,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":876296916732137473,"id_str":"876296916732137473","name":"Lulu \ud83c\uddee\ud83c\udde9\ud83c\udff8","screen_name":"lulu_chan92","location":"Bandung, Jawa Barat","url":null,"description":"#RWBY Fanartist, Illustrator, Space nerd | https:\/\/www.patreon.com\/lulu_chan92 | IG: lulu_chan92 |","translator_type":"none","protected":false,"verified":false,"followers_count":5883,"friends_count":278,"listed_count":29,"favourites_count":2217,"statuses_count":1536,"created_at":"Sun Jun 18 04:34:00 +0000 2017","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":null,"contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"1B95E0","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1139456570637443072\/bfR7xBYA_normal.jpg","profile_image_ ...

# %% [markdown]
# ### 3. Relating the data set with a dictionary of words with polarity (essential to calculating the sentiment of each tweet).

# %%
tweets_data, x, y, k, some_milby = [], [], [], [], []

def getdata(dataurl):
    print_x("Retrieving TXT File")
    tweets_data_path = dataurl
    tweets_file = open(tweets_data_path, "r")
    for line in tweets_file:
        try:
            tweet = json.loads(line)
            tweets_data.append(tweet)
        except:
            continue
    print_x("Retrieving Successfull")
    time.sleep(3)
    processdata()


def processdata():
    print_x("Recovering Data Teets")
    time.sleep(1)
    RE_EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
    for i in range(len(tweets_data)):
        q = tweets_data[i]['text']
        o = tweets_data[i]['id_str']
        q = RE_EMOJI.sub(r'', q)
        i = q.translate(str.maketrans('', '', string.punctuation))
        x.append(i)
        k.append(o)
    print_x("Data Tweets Recovered")


def readdict(dataurl):
    print_x("Reading Dictionary")
    with open(dataurl) as tsvfile:
        reader = csv.reader(tsvfile, delimiter='\t')
        for row in reader:
            i = []
            i.append(row[2])
            i.append(row[5])
            y.append(i)
    print_x("Dictionary Preparation Done")
    addpolarity()


def addpolarity():
    start_time = time.time()
    counter = 0
    print_x("Processing please wait...")

    for j in x:
        tweet_token = j
        token = word_tokenize(tweet_token)
        sumnum = 0
        sum_word = 0
        for t in token:
            for d in y:
                if t == d[0]:
                    sentiment = d[1]
                    if sentiment == "positive":
                        sumnum += 1
                        sum_word += 1

                    elif sentiment == "negative":
                        sumnum += -1
                        sum_word += 1

                    else:
                        sumnum += 0
                        sum_word += 1
                    break

        if sum_word != 0.0:
            sum_more = sumnum / sum_word
            if sum_more >= 0.2:
                sum_more = 1
            elif (sum_more < 0.2) and (sum_more > -0.5):
                sum_more = 0
            elif sum_more <= -0.5:
                sum_more = -1
            else:
                print_x("****")

        sum_var = []
        varid = k[counter]
        sum_var.append(varid)
        sum_var.append(sum_more)
        some_milby.append(sum_var)
        counter += 1

    print_x("Processing time: " + str(round(
        (time.time() - start_time), 8)) + "Seconds",)

    time.sleep(3)

    print_x("Processing Finish")
    savetoxlsx()


def savetoxlsx():
    df = pd.DataFrame(some_milby)
    df.to_excel(
        'data/processed_output.xlsx',
        header=("id", "sentiment"), 
        index=False,
    )
    print_x("Data Saved!")


def runall():
    getdata('data/tweetdata.txt')
    readdict('data/dictionary.tsv')


runall()
# Out:
# LOG => Retrieving TXT File
#
# LOG => Retrieving Successfull
#
# LOG => Recovering Data Teets
#
# LOG => Data Tweets Recovered
#
# LOG => Reading Dictionary
#
# LOG => Dictionary Preparation Done
#
# LOG => Processing please wait...
#
# LOG => Processing time: 0.34829974Seconds
#
# LOG => Processing Finish
#
# LOG => Data Saved!

# %% [markdown]
# ### 4. Now we have each tweet and the corresponding sentiment filtered by depressive keywords (Positive, Neutral and Negative).

# %% [markdown]
# ### 5. Now let's start training and predicting. The code will walk through the *processed_output.xlsx* file getting the tweet and the id of each sentiment. Then with the id we get the original data and feed the classifiers.

# %%
tweets_data, x, y = [], [], []
vectorizer = CountVectorizer(stop_words='english')


def retrieveTweet(data_url):
    tweets_data_path = data_url
    tweets_file = open(tweets_data_path, "r")
    for line in tweets_file:
        try:
            tweet = json.loads(line)
            tweets_data.append(tweet)
        except:
            continue


def retrieveProcessedData(Pdata_url):
    sent = pd.read_excel(Pdata_url)
    for i in range(len(tweets_data)):
        if tweets_data[i]['id'] == sent['id'][i]:
            x.append(tweets_data[i]['text'])
            y.append(sent['sentiment'][i])


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues,):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black",
                )

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')


def nbTrain():
    from sklearn.naive_bayes import MultinomialNB
    start_timenb = time.time()
    train_features = vectorizer.fit_transform(x)

    actual = y

    nb = MultinomialNB()
    nb.fit(train_features, [int(r) for r in y])

    test_features = vectorizer.transform(x)
    predictions = nb.predict(test_features)
    fpr, tpr, thresholds = metrics.roc_curve(actual, predictions, pos_label=1)
    nbscore = format(metrics.auc(fpr, tpr))
    nbscore = float(nbscore)*100

    nb_matrix = confusion_matrix(actual, predictions)
    plt.figure()
    plot_confusion_matrix(
        nb_matrix, classes=[-1, 0, 1], 
        title='Confusion matrix For NB classifier',
    )

    print_x("Naive Bayes  Accuracy : " + str(nbscore) + "%")
    print_x(" Completion Speed" + str(round((time.time() - start_timenb), 5)))


def datree():
    from sklearn import tree
    start_timedt = time.time()
    train_featurestree = vectorizer.fit_transform(x)
    actual1 = y
    test_features1 = vectorizer.transform(x)
    dtree = tree.DecisionTreeClassifier()

    dtree = dtree.fit(train_featurestree, [int(r) for r in y])

    prediction1 = dtree.predict(test_features1)
    ddd, ttt, thresholds = metrics.roc_curve(actual1, prediction1, pos_label=1)
    dtreescore = format(metrics.auc(ddd, ttt))
    dtreescore = float(dtreescore)*100
    print_x("Decision tree Accuracy : " + str(dtreescore) + "%")
    print_x(" Completion Speed" + str(round((time.time() - start_timedt), 5)))

def Tsvm():
    from sklearn.svm import SVC
    start_timesvm = time.time()
    train_featuressvm = vectorizer.fit_transform(x)
    actual2 = y
    test_features2 = vectorizer.transform(x)
    svc = SVC()

    svc = svc.fit(train_featuressvm, [int(r) for r in y])
    prediction2 = svc.predict(test_features2)
    sss, vvv, thresholds = metrics.roc_curve(actual2, prediction2, pos_label=1)
    svc = format(metrics.auc(sss, vvv))
    svc = float(svc)*100
    print_x("Support vector machine Accuracy : " + str(svc) + "%")
    print_x(" Completion Speed" + str(round((time.time() - start_timesvm), 5)))


def knN():
    from sklearn.neighbors import KNeighborsClassifier
    start_timekn = time.time()
    train_featureskn = vectorizer.fit_transform(x)
    actual3 = y
    test_features3 = vectorizer.transform(x)
    kn = KNeighborsClassifier(n_neighbors=2)

    kn = kn.fit(train_featureskn, [int(i) for i in y])
    prediction3 = kn.predict(test_features3)
    kkk, nnn, thresholds = metrics.roc_curve(actual3, prediction3, pos_label=1)
    kn = format(metrics.auc(kkk, nnn))
    kn = float(kn)*100

    print_x("Kneighborsclassifier Accuracy : " + str(kn) + "%")
    print_x(" Completion Speed" + str(round((time.time() - start_timekn), 5)))


def RanFo():
    from sklearn.ensemble import RandomForestClassifier
    start_timerf = time.time()
    train_featuresrf = vectorizer.fit_transform(x)
    actual4 = y
    test_features4 = vectorizer.transform(x)
    rf = RandomForestClassifier(max_depth=2, random_state=0)

    rf = rf.fit(train_featuresrf, [int(i) for i in y])
    prediction4 = rf.predict(test_features4)
    rrr, fff, thresholds = metrics.roc_curve(actual4, prediction4, pos_label=1)
    kn = format(metrics.auc(rrr, fff))
    kn = float(kn)*100
    print_x("Random Forest Accuracy : " + str(kn) + "%")
    print_x(" Completion Speed" + str(round((time.time() - start_timerf), 5)))


def runall():
    retrieveTweet('data/tweetdata.txt')
    retrieveProcessedData('data/processed_output.xlsx')
    nbTrain()
    datree()
    Tsvm()
    knN()
    RanFo()


def datreeINPUT(inputtweet):
    from sklearn import tree
    train_featurestree = vectorizer.fit_transform(x)
    dtree = tree.DecisionTreeClassifier()

    dtree = dtree.fit(train_featurestree, [int(r) for r in y])

    inputdtree = vectorizer.transform([inputtweet])
    predictt = dtree.predict(inputdtree)

    if predictt == 1:
        predictt = "Positive"
    elif predictt == 0:
        predictt = "Neutral"
    elif predictt == -1:
        predictt = "Negative"
    else:
        print("Nothing")

    print_x(f'predictt: {predictt}')


runall()

print("Input your tweet : ")
inputtweet = input()

datreeINPUT(inputtweet)
# Out:
# /home/falmeida/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/falmeida/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# LOG => Naive Bayes  Accuracy : 100.0%
#
# LOG =>  Completion Speed0.06833
#
# LOG => Decision tree Accuracy : 100.0%
#
# LOG =>  Completion Speed0.00622
#
# LOG => Support vector machine Accuracy : 50.0%
#
# LOG =>  Completion Speed0.0065
#
# LOG => Kneighborsclassifier Accuracy : 73.6517719568567%
#
# LOG =>  Completion Speed0.00632
#
# LOG => Random Forest Accuracy : 53.00462249614791%
#
# LOG =>  Completion Speed0.01046
#
# Input your tweet :
# bad
# LOG => predictt: Negative

# %% [markdown]
# 6. But one more thing! We have now also the ability to wrote a tweet and check how it performs through the model we made!
#
# `stream.filter(track=['depression', 'anxiety', 'mental health', 'suicide', 'stress', 'sad'])`

# %% [markdown]
# What about the results?
#
# #### Positive
# This mean that the person is unlikely to have depression or anxiety.
#
# #### Neutral
# This is the middle level wherein the user may or may not have depression but may also be more prone to being depress. At that stage the user may display some depressino symptoms.
#
# #### Negative
# Is the lowest level where depression and anxiety symptoms are being detected through the users tweets. The more negative words the user uses mean the more negative emotion the tweet has.

# %% [markdown]
# ### References
#
# Ma, Long & Wang, Zhibo & Zhang, Yanqing. (2017). Extracting Depression Symptoms from Social Networks and Web Blogs via Text Mining. 325-330. 10.1007/978-3-319-59575-7_29.
#
# https://github.com/niquejoe/Classification-of-Depression-on-Social-Media-Using-Text-Mining
