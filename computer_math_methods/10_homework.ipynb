# %%
# pi1
import networkx as nx
import matplotlib.pyplot as plt
import math

N = 10#480
G = nx.Graph()
positions_dict = {}
r = 10

r_custom = range(-N+1, N)
for i in r_custom:
    G.add_node(i)
    
for i in r_custom:
    x = i/N 
    y = math.sqrt(-x ** 2 + r ** 2)
    positions_dict[i] = [x, y]
    
for i in r_custom:
    if i != N-1:
        G.add_edge(i, i+1)

setd = G.degree()
nx.draw(G, node_size=100, alpha=1.0, node_color='red', with_labels=False, pos=positions_dict)
print(positions_dict)
plt.show()
# Out:
# {-9: [-0.9, 9.959417653658269], -8: [-0.8, 9.96794863550169], -7: [-0.7, 9.975469913743412], -6: [-0.6, 9.981983770774224], -5: [-0.5, 9.987492177719089], -4: [-0.4, 9.991996797437437], -3: [-0.3, 9.995498987044119], -2: [-0.2, 9.99799979995999], -1: [-0.1, 9.999499987499375], 0: [0.0, 10.0], 1: [0.1, 9.999499987499375], 2: [0.2, 9.99799979995999], 3: [0.3, 9.995498987044119], 4: [0.4, 9.991996797437437], 5: [0.5, 9.987492177719089], 6: [0.6, 9.981983770774224], 7: [0.7, 9.975469913743412], 8: [0.8, 9.96794863550169], 9: [0.9, 9.959417653658269]}
